# %%
import torch
import sys
from matplotlib import pyplot as plt
sys.path.append("../")
from src import visualize

# %%
visualize.metrics.plot_loss("sqlite:///mlflow.db", "fdf9e6a9fec24e68828da2f7926fd8fb")

# %%
visualize.metrics.plot_metric("sqlite:///mlflow.db", "fdf9e6a9fec24e68828da2f7926fd8fb", "val_Accuracy")
